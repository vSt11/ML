# %%
import numpy as np
import matplotlib.pyplot as plt
# !pip install scikit-learn
from sklearn.linear_model import LinearRegression
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.3.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.1 MB)
#      |████████████████████████████████| 11.1 MB 9.7 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17.3 in /home/raphi/.local/lib/python3.8/site-packages (from scikit-learn) (1.21.5)
# Requirement already satisfied: scipy>=1.5.0 in /home/raphi/.local/lib/python3.8/site-packages (from scikit-learn) (1.10.1)
# Collecting joblib>=1.1.1
#   Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#      |████████████████████████████████| 302 kB 8.9 MB/s eta 0:00:01
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Installing collected packages: joblib, threadpoolctl, scikit-learn
# Successfully installed joblib-1.3.2 scikit-learn-1.3.0 threadpoolctl-3.2.0

# %% [markdown]
# ## Exercice 1: Utilisation de scikit-learn pour la regression lineaire

# %%
#generation de donnees test
n = 100
x = np.arange(n)
y = np.random.randn(n)*30 + 50. * np.log(1 + np.arange(n))

# instanciation de sklearn.linear_model.LinearRegression
lr = LinearRegression()
lr.fit(x[:, np.newaxis], y)  # np.newaxis est utilise car x doit etre une matrice 2d avec 'LinearRegression'

# representation du resultat
fig = plt.figure()
plt.plot(x, y, 'r.')
plt.plot(x, lr.predict(x[:, np.newaxis]), 'b-')
plt.legend(('Data', 'Linear Fit'), loc='lower right')
plt.title('Linear regression')
plt.show()
print(lr.predict([[105]]))
# Out:
# [260.0850276]

# %% [markdown]
# ### <span style="color:blue">QUESTION 1.1 :</span>
# Expliquer ce qu'est *lr* et ce que font *lr.fit* et *lr.predict*

# %% [markdown]
# ### <span style="color:blue">REPONSE 1.1 :</span>
# lr fait une régression linéaire
# lr.fit entraine le modèle
# lr.predict utilise le modèle entrainé pour prédire une valeur de sortie à partir d'une valeur d'entrée

# %% [markdown]
# ### <span style="color:blue">QUESTION 1.2 :</span>
#
# On s'interesse à x=105. En supposant que le model lineaire soit toujours valide pour ce x, quelle valeur corresondante de y vous semble la plus vraisemblable ?
#
# On remarquera que les valeurs données pour la prediction doivent être dans un vecteur colonne, ici une matrice 1x1.

# %% [markdown]
# ### <span style="color:blue">REPONSE 1.2 :</span>

# %%
# Faire la prédiction en utilisant le modèle lr
y_predicted = lr.predict(np.array([[105]]))

# Afficher la valeur prédite de y
print("La valeur prédite de y pour x=105 est :", y_predicted[0])
# Out:
# La valeur prédite de y pour x=105 est : 259.88421507197256
